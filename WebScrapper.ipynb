# %%
from urllib.request import urlopen
html = urlopen("https://www.babynamesdirect.com/baby-names/indian/")

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html)
# Out:
# /home/dhoni/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/dhoni/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
print (soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    Indian Baby Names » Boys &amp; Girls » Beginning with A-Z » www.babynamesdirect.com
#   </title>
#   <meta content="a-z, babyname, babynames, beginning, bharat, bharatiya, book, born, boy, boys, database, fiji, girl, girls, india, indian, indians, inidian, mauritius, nepal, newborn, sanskrit, startfrom" name="keywords"/>
#   <meta content="A to Z Baby Girl Names, A to Z Baby Boys Names. Currently we have 36542 Boys Names and 26738 Girls Names with Meanings in our Indian collection. Total collection of 63280 baby names" name="description"/>
#   <link href="https://www.babynamesdirect.com/baby-names/indian/" rel="canonical"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="516732425098132" property="fb:app_id"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="INDEX,FOLLOW,NOARCHIVE" name="robots"/>
# ...

# %%
soup.a
# Out:
# <a href="https://www.babynamesdirect.com/">BabyNamesDirect</a>

# %%
soup.find_all("a")
# Out:
# [<a href="https://www.babynamesdirect.com/">BabyNamesDirect</a>,
#  <a href="https://www.babynamesdirect.com/">BabyNamesDirect</a>,
#  <a href="https://www.babynamesdirect.com/">⌂</a>,
#  <a href="https://www.babynamesdirect.com/baby-names/arabic/">Arabic/Muslim</a>,
#  <a href="https://www.babynamesdirect.com/baby-names/australian/">Australian</a>,
#  <a href="https://www.babynamesdirect.com/baby-names/english/">English</a>,
#  <a href="https://www.babynamesdirect.com/baby-names/french/">French</a>,
#  <a href="https://www.babynamesdirect.com/baby-names/german/">German</a>,
#  <a href="https://www.babynamesdirect.com/baby-names/indian/">Indian</a>,
#  <a href="https://www.babynamesdirect.com/baby-names/indian/">All Names</a>,
#  <a href="https://www.babynamesdirect.com/baby-names/assamese/">Assamese</a>,
#  <a href="https://www.babynamesdirect.com/baby-names/bengali/">Bengali</a>,
#  <a href="https://www.babynamesdirect.com/baby-names/gujarati/">Gujarati</a>,
# ...

# %%
all_links = soup.find_all("a")
all_m = []
#cha = "indian/boy"
for link in all_links:
    if "indian/boy" in link.get('href'):
        all_m.append(link.get('href'))
      
all_f = []
for link in all_links:
    if "indian/girl" in link.get('href'):
        all_f.append(link.get('href'))

# %%
all_m
# Out:
# ['https://www.babynamesdirect.com/baby-names/indian/boy/a',
#  'https://www.babynamesdirect.com/baby-names/indian/boy/b',
#  'https://www.babynamesdirect.com/baby-names/indian/boy/c',
#  'https://www.babynamesdirect.com/baby-names/indian/boy/d',
#  'https://www.babynamesdirect.com/baby-names/indian/boy/e',
#  'https://www.babynamesdirect.com/baby-names/indian/boy/f',
#  'https://www.babynamesdirect.com/baby-names/indian/boy/g',
#  'https://www.babynamesdirect.com/baby-names/indian/boy/h',
#  'https://www.babynamesdirect.com/baby-names/indian/boy/i',
#  'https://www.babynamesdirect.com/baby-names/indian/boy/j',
#  'https://www.babynamesdirect.com/baby-names/indian/boy/k',
#  'https://www.babynamesdirect.com/baby-names/indian/boy/l',
#  'https://www.babynamesdirect.com/baby-names/indian/boy/m',
#  'https://www.babynamesdirect.com/baby-names/indian/boy/n',
#  'https://www.babynamesdirect.com/baby-names/indian/boy/o',
#  'https://www.babynamesdirect.com/baby-names/indian/boy/p',
# ...

# %%
import pandas as pd
df = pd.DataFrame(all_m, columns=["webpage"])
df.to_csv('male.csv', index=False)

# %%
import pandas as pd
df = pd.DataFrame(all_f, columns=["webpage"])
df.to_csv('female.csv', index=False)

# %%
html1 = urlopen(df1.webpage[0])
print (df1.webpage[0])
# Out:
# https://www.babynamesdirect.com/baby-names/indian/boy/a

# %%
soup1 = BeautifulSoup(html1)
# Out:
# /home/dhoni/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/dhoni/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
soup1.find_all("a")
# Out:
# [<a href="https://www.babynamesdirect.com/">BabyNamesDirect</a>,
#  <a href="https://www.babynamesdirect.com/">BabyNamesDirect</a>,
#  <a href="https://www.babynamesdirect.com/">⌂</a>,
#  <a href="https://www.babynamesdirect.com/baby-names/arabic/">Arabic/Muslim</a>,
#  <a href="https://www.babynamesdirect.com/baby-names/australian/">Australian</a>,
#  <a href="https://www.babynamesdirect.com/baby-names/english/">English</a>,
#  <a href="https://www.babynamesdirect.com/baby-names/french/">French</a>,
#  <a href="https://www.babynamesdirect.com/baby-names/german/">German</a>,
#  <a href="https://www.babynamesdirect.com/baby-names/indian/">Indian</a>,
#  <a href="https://www.babynamesdirect.com/baby-names/indian/">All Names</a>,
#  <a href="https://www.babynamesdirect.com/baby-names/assamese/">Assamese</a>,
#  <a href="https://www.babynamesdirect.com/baby-names/bengali/">Bengali</a>,
#  <a href="https://www.babynamesdirect.com/baby-names/gujarati/">Gujarati</a>,
# ...

# %%
all_links = soup1.find_all("a")
all_a = []
#cha = "indian/boy"
for link in all_links:
    if ".com/boy/" in link.get('href'):
            if link in all_a:
                end
            else:
                all_a.append(link.get('href'))

# %%
all_a = [x[36:] for x in all_a]

# %%
df = pd.DataFrame(all_a, columns=["names"])
df.to_csv('male_name.csv', index=False)

# %%
for x in df:
    i = len(x)-2
    x = x[1:i]

# %%
all_links = soup1.find_all("a")
all_a_links = []
#cha = "indian/boy"
for link in all_links:
    if "indian/boy/a/" in link.get('href'):
            if link in all_a_links:
                end
            else:
                all_a_links.append(link.get('href'))

# %%
all_a_links
# Out:
# ['https://www.babynamesdirect.com/baby-names/indian/boy/a/3',
#  'https://www.babynamesdirect.com/baby-names/indian/boy/a/4',
#  'https://www.babynamesdirect.com/baby-names/indian/boy/a/5',
#  'https://www.babynamesdirect.com/baby-names/indian/boy/a/51',
#  'https://www.babynamesdirect.com/baby-names/indian/boy/a/3']

# %%
df2 = pd.DataFrame(all_a_links, columns=["names"])
df2.to_csv('male_name.csv', index=False)

# %%
html2 = urlopen(df2.names[0])
print (html2)

# %%
soup2 = BeautifulSoup(html2)
# Out:
# /home/dhoni/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/dhoni/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
print (soup2.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    Indian Baby Names » Boy Names » Starting From A » Page 3/51 » www.babynamesdirect.com
#   </title>
#   <meta content="baby, babyname, babynames, bharat, bharatiya, book, born, boys, database, fiji, india, indian, indians, inidian, male, mauritius, nepal, newborn, sanskrit" name="keywords"/>
#   <meta content="Boys Names A to Z - Baby Boy Name - Meanings; Currently we have 5073 Boys Names Beginning with letter A in our Indian collection" name="description"/>
#   <link href="https://www.babynamesdirect.com/baby-names/indian/boy/a/3" rel="canonical"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="516732425098132" property="fb:app_id"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="INDEX,FOLLOW,NOARCHIVE" name="robots"/>
#   <meta content="https://www.babynamesdirect.com/images/b/cute-child-61.jpg" property="og:image"/>
# ...

# %%
all_links = soup2.find_all("a")
#cha = "indian/boy"
#for link in all_links:
#    link = link.get('href')
#    if "indian/boy/a/" in link and link not in all_a_links:
#                all_a_links.append(link)
all_links = [link.get('href') for link in all_links]
for link in all_links:
#    link = link.get('href')
    if "indian/boy/a/" in link and link not in all_a_links:
                all_a_links.append(link)

# %%
all_a_links
# Out:
# ['https://www.babynamesdirect.com/baby-names/indian/boy/a/3',
#  'https://www.babynamesdirect.com/baby-names/indian/boy/a/4',
#  'https://www.babynamesdirect.com/baby-names/indian/boy/a/5',
#  'https://www.babynamesdirect.com/baby-names/indian/boy/a/51',
#  'https://www.babynamesdirect.com/baby-names/indian/boy/a/3',
#  'https://www.babynamesdirect.com/baby-names/indian/boy/a/2']
